# %% [markdown]
# # Python Requests

# %% [markdown]
# ## Tasks Today:
#
#
# 1) <b>Requests package</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) pip install <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) requests.get <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Response object <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) .content and .text <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) JSON <br>
# 2) <b>Python Wrapper</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) API key and base url<br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Creating a class for our requests<br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Private method for getting the response data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Public method for displaying the data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) In-Class Exercise #1 - Add a method for getting the high and lows for the next 3 days <br>
# 3) <b>Exercises</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Exercise #1 - Pokemon Wrapper  <br>

# %%
# !pip install faker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 6.5 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from faker import Faker

fake = Faker()

# %%
data = []
for _ in range(10):
    first = fake.first_name()
    last = fake.last_name()
    person_info = {
        'first_name': first,
        'last_name': last,
        'city': fake.city(),
        'email': f'{first.lower()}.{last.lower()}@{fake.domain_name()}',
        'occupation': {
            'company': fake.company(),
            'position': fake.job()
        }
    }
    data.append(person_info)

# %% [markdown]
# #### Warm Up
# Write a function that takes in a name (first or last) and returns the position and company name of that person. If the user is not found, return -1

# %%
# !python3 --version
# Out:
# Python 3.10.10

# %%
# Example 1
# get_person_info('Adam')
# Output: 'Records manager at Odom, Harper, and Allen'

# Example 2
# get_person_info('Burns')
# Output: 'Applications developer at Sanders-Ryan'

# Example 3
# get_person_info('Alice')
# Output: -1

# %%
data = [
    {
        'first_name': 'Adam',
        'last_name': 'Simpson',
        'city': 'West Maureenland',
        'email': 'adam.simpson@paul-williams.com',
        'occupation': {
            'company': 'Odom, Harper and Allen',
            'position': 'Records manager'
        }
    },
    {
        'first_name': 'Robert',
        'last_name': 'Miller',
        'city': 'South Jaredburgh',
        'email': 'robert.miller@allen.org',
        'occupation': {
            'company': 'Roberts-Jackson',
            'position': 'Media planner'
        }
    },
    {
        'first_name': 'Edwin',
        'last_name': 'Johnson',
        'city': 'Lake Kimberly',
        'email': 'edwin.johnson@sanders.biz',
        'occupation': {
            'company': 'Hart, Jones and Malone',
            'position': 'Therapist, speech and language'
        }
    },
    {
        'first_name': 'Gail',
        'last_name': 'Castro',
        'city': 'Brianchester',
        'email': 'gail.castro@suarez-sullivan.org',
        'occupation': {
            'company': 'Duncan-Gallagher',
            'position': 'Designer, multimedia'
        }
    },
    {
        'first_name': 'Andre',
        'last_name': 'Burns',
        'city': 'New Samuelside',
        'email': 'andre.burns@love.com',
        'occupation': {
            'company': 'Sanders-Ryan',
            'position': 'Applications developer'
        }
    },
    {
        'first_name': 'Nicole',
        'last_name': 'Maynard',
        'city': 'Teresaville',
        'email': 'nicole.maynard@chavez.com',
        'occupation': {
            'company': 'Hoffman, Reynolds and Wilson',
            'position': 'Community education officer'
        }
    },
    {
        'first_name': 'Megan',
        'last_name': 'Mcdonald',
        'city': 'Walkerfurt',
        'email': 'megan.mcdonald@guzman.info',
        'occupation': {
            'company': 'King Ltd',
            'position': 'Doctor, general practice'
        }
    },
    {
        'first_name': 'Stephen',
        'last_name': 'Young',
        'city': 'South Jeffrey',
        'email': 'stephen.young@smith.biz',
        'occupation': {
            'company': 'Hernandez LLC',
            'position': 'Environmental manager'
        }
    },
    {
        'first_name': 'Daniel',
        'last_name': 'Deleon',
        'city': 'Yatesburgh',
        'email': 'daniel.deleon@mcmahon.org',
        'occupation': {
            'company': 'Nelson-Wilson',
            'position': 'Sports development officer'
        }
    },
    {
        'first_name': 'Patricia',
        'last_name': 'Pacheco',
        'city': 'South Donnamouth',
        'email': 'patricia.pacheco@lee-wilson.com',
        'occupation': {
            'company': 'Giles, Williams and Jones',
            'position': 'Theatre manager'
        }
    }
]

def get_person_info(name):
    human = [person for person in data if name in {person['first_name'],person['last_name']}]
    if not len(human):
        return -1
    return f"{human[0]['occupation']['position']} at {human[0]['occupation']['company']}"

# %%
get_person_info('Adam')
# Out:
# 'Records manager at Odom, Harper and Allen'

# %%
get_person_info('Burns')
# Out:
# 'Applications developer at Sanders-Ryan'

# %%
get_person_info('Alice')
# Out:
# -1

# %% [markdown]
# ### Requests Package
# <a href='https://docs.python-requests.org/en/latest/'>Docs</a>

# %% [markdown]
# #### Install and import package

# %%
# !pip install requests
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import requests

requests
# Out:
# <module 'requests' from '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/__init__.py'>

# %% [markdown]
# #### requests get method

# %%
res = requests.get('https://www.codingtemple.com')
res
# Out:
# <Response [200]>

# %% [markdown]
# #### Response object

# %%
print(type(res))
# Out:
# <class 'requests.models.Response'>

# %%
help(res)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
# ...

# %% [markdown]
# #### .content

# %%
print(res.content)
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="en-US">\r\n\r\n<head>\r\n    <meta charset="UTF-8" />\r\n    <!--<meta name="viewport" content="width=device-width, initial-scale=1" />-->\r\n    <meta content=\'width=device-width, initial-scale=1, minimum-scale=1\' name=\'viewport\'/>\r\n    <meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n\t<!-- This site is optimized with the Yoast SEO Premium plugin v20.1 (Yoast SEO v20.1) - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Coding Temple | Tech Bootcamp in Software, Data, &amp; Front-End</title>\n\t<meta name="description" content="Break into tech with Coding Temple, a top-ranked online Software Engineering, Data Analytics, Front-End Development, &amp; Blockchain Bootcamp! Enroll today!" />\n\t<link rel="canonical" href="https://www.codingtemple.com/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:type" content="website" />\n\t<meta property="o
# ...

# %% [markdown]
# #### .text

# %%
print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#
# <head>
#     <meta charset="UTF-8" />
#     <!--<meta name="viewport" content="width=device-width, initial-scale=1" />-->
#     <meta content='width=device-width, initial-scale=1, minimum-scale=1' name='viewport'/>
#     <meta name='robots' content='index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1' />
#
# 	<!-- This site is optimized with the Yoast SEO Premium plugin v20.1 (Yoast SEO v20.1) - https://yoast.com/wordpress/plugins/seo/ -->
# 	<title>Coding Temple | Tech Bootcamp in Software, Data, &amp; Front-End</title>
# 	<meta name="description" content="Break into tech with Coding Temple, a top-ranked online Software Engineering, Data Analytics, Front-End Development, &amp; Blockchain Bootcamp! Enroll today!" />
# 	<link rel="canonical" href="https://www.codingtemple.com/" />
# 	<meta property="og:locale" content="en_US" />
# 	<meta property="og:type" content="website" />
# ...

# %%
print(res.ok)
# Out:
# True

# %% [markdown]
# #### JSON Response

# %%
res = requests.get('https://pokeapi.co/api/v2/pokemon/pikachu')
res
# Out:
# <Response [200]>

# %%
res.content
# Out:
# b'{"abilities":[{"ability":{"name":"static","url":"https://pokeapi.co/api/v2/ability/9/"},"is_hidden":false,"slot":1},{"ability":{"name":"lightning-rod","url":"https://pokeapi.co/api/v2/ability/31/"},"is_hidden":true,"slot":3}],"base_experience":112,"forms":[{"name":"pikachu","url":"https://pokeapi.co/api/v2/pokemon-form/25/"}],"game_indices":[{"game_index":84,"version":{"name":"red","url":"https://pokeapi.co/api/v2/version/1/"}},{"game_index":84,"version":{"name":"blue","url":"https://pokeapi.co/api/v2/version/2/"}},{"game_index":84,"version":{"name":"yellow","url":"https://pokeapi.co/api/v2/version/3/"}},{"game_index":25,"version":{"name":"gold","url":"https://pokeapi.co/api/v2/version/4/"}},{"game_index":25,"version":{"name":"silver","url":"https://pokeapi.co/api/v2/version/5/"}},{"game_index":25,"version":{"name":"crystal","url":"https://pokeapi.co/api/v2/version/6/"}},{"game_index":25,"version":{"name":"ruby","url":"https://pokeapi.co/api/v2/version/7/"}},{"game_index":25,"versi
# ...

# %%
res.text
# Out:
# '{"abilities":[{"ability":{"name":"static","url":"https://pokeapi.co/api/v2/ability/9/"},"is_hidden":false,"slot":1},{"ability":{"name":"lightning-rod","url":"https://pokeapi.co/api/v2/ability/31/"},"is_hidden":true,"slot":3}],"base_experience":112,"forms":[{"name":"pikachu","url":"https://pokeapi.co/api/v2/pokemon-form/25/"}],"game_indices":[{"game_index":84,"version":{"name":"red","url":"https://pokeapi.co/api/v2/version/1/"}},{"game_index":84,"version":{"name":"blue","url":"https://pokeapi.co/api/v2/version/2/"}},{"game_index":84,"version":{"name":"yellow","url":"https://pokeapi.co/api/v2/version/3/"}},{"game_index":25,"version":{"name":"gold","url":"https://pokeapi.co/api/v2/version/4/"}},{"game_index":25,"version":{"name":"silver","url":"https://pokeapi.co/api/v2/version/5/"}},{"game_index":25,"version":{"name":"crystal","url":"https://pokeapi.co/api/v2/version/6/"}},{"game_index":25,"version":{"name":"ruby","url":"https://pokeapi.co/api/v2/version/7/"}},{"game_index":25,"versio
# ...

# %%
res.json()
# Out:
# {'abilities': [{'ability': {'name': 'static',
#     'url': 'https://pokeapi.co/api/v2/ability/9/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'lightning-rod',
#     'url': 'https://pokeapi.co/api/v2/ability/31/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 112,
#  'forms': [{'name': 'pikachu',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}],
#  'game_indices': [{'game_index': 84,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 84,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 84,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 25,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 25,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 25,
# ...

# %%
print(type(res.content))
print(type(res.text))
print(type(res.json()))
# Out:
# <class 'bytes'>
# <class 'str'>
# <class 'dict'>

# %%
data = res.json()
data
# Out:
# {'abilities': [{'ability': {'name': 'static',
#     'url': 'https://pokeapi.co/api/v2/ability/9/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'lightning-rod',
#     'url': 'https://pokeapi.co/api/v2/ability/31/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 112,
#  'forms': [{'name': 'pikachu',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}],
#  'game_indices': [{'game_index': 84,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 84,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 84,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 25,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 25,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 25,
# ...

# %%
pokemon_name = data['name']
print(pokemon_name)
# Out:
# pikachu

# %% [markdown]
# ### Python Wrappers

# %%
base_url = 'http://api.weatherapi.com/v1'
api_method = '/current.json'
api_key = '2d1c726c6b8440c7b39194144231005'
city = 'Chennai'

request_url = f'{base_url}{api_method}?key={api_key}&q={city}'
print(request_url)
# Out:
# http://api.weatherapi.com/v1/current.json?key=2d1c726c6b8440c7b39194144231005&q=Chennai

# %%
my_api_key = 'f72035084b9043abb7d52225212212'

api_url = f'https://api.weatherapi.com/v1/current.json?key={api_key}&q={city}'

# %%
res = requests.get(api_url)
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'location': {'name': 'Chennai',
#   'region': 'Tamil Nadu',
#   'country': 'India',
#   'lat': 13.08,
#   'lon': 80.28,
#   'tz_id': 'Asia/Kolkata',
#   'localtime_epoch': 1683750387,
#   'localtime': '2023-05-11 1:56'},
#  'current': {'last_updated_epoch': 1683749700,
#   'last_updated': '2023-05-11 01:45',
#   'temp_c': 30.0,
#   'temp_f': 86.0,
#   'is_day': 0,
#   'condition': {'text': 'Mist',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#    'code': 1030},
#   'wind_mph': 5.6,
#   'wind_kph': 9.0,
#   'wind_degree': 250,
#   'wind_dir': 'WSW',
#   'pressure_mb': 1006.0,
#   'pressure_in': 29.71,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 84,
#   'cloud': 50,
#   'feelslike_c': 37.1,
#   'feelslike_f': 98.7,
#   'vis_km': 5.0,
#   'vis_miles': 3.0,
#   'uv': 1.0,
#   'gust_mph': 11.9,
#   'gust_kph': 19.1}}

# %%
class WeatherAPI:
    
    def __init__(self, api_key):
        self.base_url = 'https://api.weatherapi.com/v1'
        self.api_key = api_key
        
        
    def _get(self, q=''):
        res = requests.get(f'{self.base_url}/current.json?key={self.api_key}&q={q}')
        if res.ok:
            return res.json()
        
    def get_city_weather(self, city):
        data = self._get(city)
        display_name = f"{data['location']['name']}, {data['location']['region']}"
        current_temp = data['current']['temp_f']
        current_condition = data['current']['condition']['text']
        feels_like = data['current']['feelslike_f']
        degree_sign = u"\N{DEGREE SIGN}"
        print(f"It is currently {current_condition} and {current_temp}{degree_sign}F in {display_name}. It feels like {feels_like}{degree_sign}F")
        
        

weather = WeatherAPI(api_key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 24
#      19         degree_sign = u"\N{DEGREE SIGN}"
#      20         print(f"It is currently {current_condition} and {current_temp}{degree_sign}F in {display_name}. It feels like {feels_like}{degree_sign}F")
# ---> 24 weather = WeatherAPI(api_key)
#
# NameError: name 'api_key' is not defined

# %%
weather.get_city_weather('Chennai')
# Out:
# It is currently Mist and 86.0°F in Chennai, Tamil Nadu. It feels like 98.7°F

# %%
class CityWeather:
    def __init__(self,name,region,temp,feels_like,condition):
        self.city = name
        self.region = region
        self.temp = temp
        self.feels = feels_like
        self.condition = condition

# %%
class WeatherAPII:
    base_url = 'http://api.weatherapi.com/v1'

    def __init__(self,api_key):
        self.api_key = 'f72035084b9043abb7d52225212212'
    
    def _get(self,city,api_method):
        request_url = f'{self.base_url}{api_method}?key={self.api_key}&q={city}'
        weather_response = requests.get(request_url)
        if weather_response.ok:
            return weather_response.json()
        else:
            print('There was an error!')
    
    def get_current_weather(self,city):
        weather_data = self._get(city,'/current.json')
        if weather_data:
            display_name = f"{data['location']['name']}, {data['location']['region']}"
            current_temp = data['current']['temp_f']
            current_condition = data['current']['condition']['text']
            feels_like = data['current']['feelslike_f']
            degree_sign = u"\N{DEGREE SIGN}"
            print(f"It is currently {current_condition} and {current_temp}{degree_sign}F in {display_name}. It feels like {feels_like}{degree_sign}F")

# %%
Chicago = WeatherAPII

Chicago.get_current_weather(Chicago,'Chicago')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 3
#       1 Chicago = WeatherAPII
# ----> 3 Chicago.get_current_weather(Chicago,'Chicago')
#
# Cell In[43], line 16, in WeatherAPII.get_current_weather(self, city)
#      15 def get_current_weather(self,city):
# ---> 16     weather_data = self._get(city,'/current.json')
#      17     if weather_data:
#      18         display_name = f"{data['location']['name']}, {data['location']['region']}"
#
# TypeError: WeatherAPII._get() missing 1 required positional argument: 'api_method'

# %% [markdown]
# #### In-class Exercise

# %% [markdown]
# Add a method for getting the forecast weather for a city. It should default to 3 days in the future. It should display the high, low and condition with the date.

# %% [markdown]
# # Exercise

# %% [markdown]
# #### Pokemon API Wrapper

# %% [markdown]
# Create a python wrapper for the Pokemon API. It should take in a pokemon name and display the pokemon with its height and weight

# %%
""""
Create a Pokemon SDK/Python Wrapper for the Poke API. 
The wrapper should have a .get_pokemon() method that will return a Pokemon instance 
(you will also need to create a Pokemon class). The Pokemon instances should have attributes for 
name, height, and weight. You are encouraged to add more and use creative freedom here.
"""
import requests

from random import randint

from IPython.display import Image

class PocketMonster:

    base_url = 'https://pokeapi.co/api/v2/pokemon/'

    #moves url for battle function: https://pokeapi.co/api/v2/move/{id or name}/

    def __init__(self,name,level):
        self.name = name.title()
        self.level = level
        self.pokerequest = PocketMonster.base_url + self.name.lower()
        self.pokeresponse = requests.get(self.pokerequest)
        self.type = []
        self.pokenumber = '?'
        if not self.pokeresponse.ok:
            print('NO SUCH POKÉMON!!!')
        else:
            self.pokedata = self.pokeresponse.json()
            self.height = self.pokedata['height']
            self.weight = self.pokedata['weight']
            self.type = [t['name'] for t in [i['type'] for i in self.pokedata['types']]]
            self.pokenumber = self.pokedata['id']
            self.pokepic = [self.pokedata['sprites'][k] for k in self.pokedata['sprites'] if isinstance(self.pokedata['sprites'][k],str)][3]
            self.movelist = [move['move']['name'] for move in self.pokedata['moves'] if move['version_group_details'][0]['level_learned_at'] <= self.level]
            self.moveset = set()
            for i in range(4):
                random_move_index = randint(0,len(self.movelist)-1)
                self.moveset.add(self.movelist.pop(random_move_index))

    def __str__(self):
        return f"{self.name.title()} is Pokémon number {self.pokenumber}, a {(' and ').join([t.title() for t in self.type])} type Pokémon."
    
    def __repr__(self):
        return f"{self.name.title()}|No.{self.pokenumber}|types: {[t.title() for t in self.type]}|height: {self.height}|weight: {self.weight}"
    
    def view_pokemon(self):
        Image(url=self.pokepic)
        
    def get_pokemon(self):
        return self 

    def battle(self,other):
        if not isinstance(other,PocketMonster):
            print('Pokémon can only battle other Pokémon, silly!')
        else:
            newbattle = Battle()
        
        #a Battle class would set up an interaction and look up the pokemon's moves in the moves API to stage a battle

# %%
Tom = PocketMonster('blastoise',10)

print(Tom.pokepic)

Tom.view_pokemon()


Image(url = 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/9.png')
#Why doesn't this work??

Image(url = Tom.pokepic)

#Pokemon sprite appears only if the line below is commented out???!!! Why??!!
#Tom.view_pokemon()
# Out:
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/9.png
# <img src="https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/9.png"/>

# %%
print(Tom.moveset)
# Out:
# {'water-pledge', 'dig', 'seismic-toss', 'ice-punch'}
